# %%
import praw
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from datetime import datetime as dt

# %%
##pgsql engine
engine=create_engine('postgresql+psycopg2://postgres:6969@localhost/170final')

# %%
## create table
##replace table name
engine.execute("CREATE TABLE IF NOT EXISTS TABLE_NAME(\
                title text,\
                title_created_time timestamp,\
                comment_id text,\
                comment_created_time timestamp,\
                parent_id text,\
                body_text text,\
                likes int\
                );")

# %%
#reddit api
##replace##
reddit = praw.Reddit(client_id='ZPcEKVdZuwHy5Q', 
                     client_secret='qqfTY43w5WLco3g2-R21RMjo_bzw9A', 
                     user_agent='sentiment analysis', 
                     username='KissNeverTouch', 
                     password='918273645Cc!')

# %%
##query and subreddit field
search_query = ["covid-19"]
## replace subreddit parameter
## we used 5 subreddit: all, askreddit, Coronavirus, COVID19, Coronavirusus
subreddit = reddit.subreddit("Coronavirus")

# %%
r_comments = {
            "title" : [],
            "title_created_time" : [],
            "user_name" : [],
            "comment_id" : [],
            "comment_created_time" : [],
            "parent_id" : [],
            "body_text" : [],
            "likes" : []
        }

# %%
## for subreddit: all, askreddit
## replace below line with
#for s in subreddit.search(search_query,sort = "top",limit=1000):

for s in subreddit.top(limit=1000):
    print("Now crawle topic NO:   ",i)
    title = s.title
    title = title.replace("'",'"')
    created_at = str(dt.fromtimestamp(s.created_utc))
    
    ##limit depth = 1
    s.comments.replace_more(limit = 1)
    for c in s.comments.list():
        try:
            user_name = c.author.name
        except:
            user_name = "NA"
        comment_id = c.id
        comment_created_at = str(dt.fromtimestamp(c.created_utc))
        parent_id = c.parent_id #parent id
        body_text = c.body
        body_text = body_text.replace("'",'"')
        score = str(c.score) #the number of upvotes for the comment
        
        try:
            #store in pgSQL
            sql_str = "INSERT INTO Coronavirus VALUES('" + title +"','"+ \
                        created_at +"','"+user_name+"','"+ comment_id+"','"+comment_created_at+"','"+\
                        parent_id +"','"+ body_text + "','"+ score + "')"

            engine.execute(sql_str) 


            r_comments["title"].append(title)
            r_comments["title_created_time"].append(created_at)
            r_comments["user_name"].append(user_name)
            r_comments["comment_id"].append(comment_id)
            r_comments["comment_created_time"].append(comment_created_at)
            r_comments["parent_id"].append(parent_id)
            r_comments["body_text"].append(body_text)
            r_comments["likes"].append(score)
        except:
            pass
# Out:
# Now crawle topic NO:    1
# Now crawle topic NO:    2
# Now crawle topic NO:    3
# Now crawle topic NO:    4
# Now crawle topic NO:    5
# Now crawle topic NO:    6
# Now crawle topic NO:    7
# Now crawle topic NO:    8
# Now crawle topic NO:    9
# Now crawle topic NO:    10
# Now crawle topic NO:    11
# Now crawle topic NO:    12
# Now crawle topic NO:    13
# Now crawle topic NO:    14
# Now crawle topic NO:    15
# Now crawle topic NO:    16
# Now crawle topic NO:    17
# Now crawle topic NO:    18
# Now crawle topic NO:    19
# Now crawle topic NO:    20
# Now crawle topic NO:    21
# Now crawle topic NO:    22
# Now crawle topic NO:    23
# Now crawle topic NO:    24
# Now crawle topic NO:    25
# Now crawle topic NO:    26
# Now crawle topic NO:    27
# Now crawle topic NO:    28
# Now crawle topic NO:    29
# Now crawle topic NO:    30
# Now crawle topic NO:    31
# Now crawle topic NO:    32
# Now crawle topic NO:    33
# Now crawle topic NO:    34
# ...

# %%
comments = pd.DataFrame(r_comments)
